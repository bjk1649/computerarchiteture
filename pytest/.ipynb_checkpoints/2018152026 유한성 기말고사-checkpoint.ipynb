# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./Life_expectancy.csv",sep=',')

# %%
data
# Out:
#           Country  Year      Status  Life expectancy  Adult mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
#3번

new_data = np.array(data)

# %%
#3번 중복되는 관측치 제거
non_dupli_data=data.drop_duplicates(keep='first')

# %%
#3번 중복되는 관측치의 수를 출력
new_data = np.array(data)
X= np.array(non_dupli_data)

result=len(new_data) - len(X) 
print(result)
# Out:
# 0

# %%
#6번

Y=data["Life expectancy"]
X=data.drop(["Life expectancy"],axis=1)

# %%
#4번 

data2 = pd.get_dummies(data['Status'])

# %%
#6번 


X_train = X.iloc[:137,]
X_test = X.iloc[137:171,]
Y_train = Y.iloc[:137]
Y_test = Y.iloc[137:171]

# %%
#7번

class MLR:
    def __init__(self,Intercept=True):
        self.Intercept=Intercept
        
    def Intercept_add(self,X(input)):
        ones = dataFrame()
        ones.reshape(-1,1)
        self.X = pd.concat([X(input),ones], axis=0)
        return self.X

# %%
#8번

class Knn:
    
    def __init__(self,n_neighbor=5):
        self.n_neighbor=n_neighbor
        self.neigh_index=list()
        
    def eucladiean_dist(self,obs1,obs2):
        dist=np.sqrt(np.sum(obs1-obs2)**2)
        return np.round(dist,3)
    
    def search_neighbors(self,X_train,test_sample_x):
        dists_info=list()
        for index, train_sample in enumerate(X_train):
            dist=self.eucladiean_dist(train_sample,test_sample_x)
            dists_info.append((train_sample,dist,index))
        dists_info.sort(key=lambda tupe:tupe[1])
        n_neighbors=dists_info[:self.n_neighbor]
        for neigh in n_neighbors:
            self.neigh_indx.append(neigh[2])
        return self.neigh_index
    
    def predict(self,X_train,Y_train,X_test):
        total_predict=list()
        for test_sample_x in X_test:
            self.neigh_index= self.search_neighbors(X_train,test_sample_x)
            neigh_Y = Y_train[self.neigh_index]            
            classes,count = np.unique(neigh_Y,return_counts=True)
            pred = classes[np.argmax(counts)]  
            total_predict.append(pred)
        return total_predict

# %%
knn =Knn(5)

# %%
#9번 MSE함수

def MSE(true_y,pred_y):
    mse=np.sqrt(np.mean(true_y-pred_y)**2)
    return MSE

# %%
#9번 MAPE함수 정의

def MAPE(trie_y,pred_y):
    maple=nnp.sqrt(np.mean((true_y-pred_y)/(treu_y))**2)
    return MAPE

# %%
#10번 KNN예측결과 
total_knn_accuracy = np.mean(knn.predict(X_train,Y_train,X_test)==Y_test)*100

# %%
#10번

print("MSE 지표 : Knn:{:.1f} vs MLR:{:.1f}",format((total_knn_accuracy)*100,()))
print("MAPE 지표 : Knn:{:.1f} vs MLR:{:.1f}",format((total_knn_accuracy)*100,()))
