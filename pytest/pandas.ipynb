# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
### 데이터 불러오기

# %%
dataset = pd.read_csv("./Life_expectancy.csv")

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria   HIV/AIDS         GDP  Population  \
# ...

# %%
dataset['Status'].unique() ### status에 무슨 값이 있는지 확인
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
dataset.tail(10)
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 2928  Zimbabwe  2009  Developing             50.0            587.0
# 2929  Zimbabwe  2008  Developing             48.2            632.0
# 2930  Zimbabwe  2007  Developing             46.6             67.0
# 2931  Zimbabwe  2006  Developing             45.4              7.0
# 2932  Zimbabwe  2005  Developing             44.6            717.0
# 2933  Zimbabwe  2004  Developing             44.3            723.0
# 2934  Zimbabwe  2003  Developing             44.5            715.0
# 2935  Zimbabwe  2002  Developing             44.8             73.0
# 2936  Zimbabwe  2001  Developing             45.3            686.0
# 2937  Zimbabwe  2000  Developing             46.0            665.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 2928             30     4.64                1.040021         73.0      853
# 2929             30     3.56               20.843429         75.0        0
# ...

# %%
dataset.describe()
# Out:
#               Year  Life expectancy  Adult mortality  Infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  Percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
dataset['Infant deaths'].hist()##life expectancy를 히스토그램으로 표현
# Out:
# <AxesSubplot:>

# %%
dataset['Life expectancy'].hist(bins=30, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
subdata_1 = dataset.iloc[0:100,1:6] ## 2번쨰 속성에서 5번째 속성까지 100개의 튜플 가져옴
print(subdata_1.shape)
subdata_1.head()
# Out:
# (100, 5)
#    Year      Status  Life expectancy  Adult mortality  Infant deaths
# 0  2015  Developing             65.0            263.0             62
# 1  2014  Developing             59.9            271.0             64
# 2  2013  Developing             59.9            268.0             66
# 3  2012  Developing             59.5            272.0             69
# 4  2011  Developing             59.2            275.0             71

# %%
indices = np.array(dataset.index)

# %%
indices
# Out:
# array([   0,    1,    2, ..., 2935, 2936, 2937], dtype=int64)

# %%
condition1 = dataset['Population']>=(1000*10000)

# %%
condition1
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2933     True
# 2934     True
# 2935    False
# 2936     True
# 2937     True
# Name: Population, Length: 2938, dtype: bool

# %%
condition2 = dataset['Life expectancy'] <=60

# %%
condition2
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2933     True
# 2934     True
# 2935     True
# 2936     True
# 2937     True
# Name: Life expectancy, Length: 2938, dtype: bool

# %%
condition1 & condition2
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2933     True
# 2934     True
# 2935    False
# 2936     True
# 2937     True
# Length: 2938, dtype: bool

# %%
indices1=indices[condition1&condition2]

# %%
subdata_5=dataset.loc[indices1]

# %%
subdata_5['Country'].unique()
# Out:
# array(['Afghanistan', 'Angola', 'Burkina Faso', 'Cambodia', 'Cameroon',
#        'Chad', 'Ethiopia', 'Ghana', 'Guinea', 'Kenya', 'Madagascar',
#        'Malawi', 'Mali', 'Mozambique', 'Myanmar', 'Niger', 'Nigeria',
#        'South Africa', 'South Sudan', 'Sudan', 'Uganda', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
dataset.isnull().mean() ## 각 변수별로 미싱밸류 비율 알 수 있음
# Out:
# Country                            0.000000
# Year                               0.000000
# Status                             0.000000
# Life expectancy                    0.003404
# Adult mortality                    0.003404
# Infant deaths                      0.000000
# Alcohol                            0.066031
# Percentage expenditure             0.000000
# Hepatitis B                        0.188223
# Measles                            0.000000
# BMI                                0.011572
# Under-five deaths                  0.000000
# Polio                              0.006467
# Total expenditure                  0.076923
# Diphtheria                         0.006467
# HIV/AIDS                           0.000000
# GDP                                0.152485
# Population                         0.221920
# Thinness 1-19 years                0.011572
# Thinness 5-9 years                 0.011572
# Income composition of resources    0.056841
# ...

# %%
null_indices = indices[dataset.isnull().any(axis=1)] ##미싱밸류가 하나라도 있는 튜플의 인덱스추출

# %%
dataset.loc[null_indices]
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 32     Algeria  2015  Developing             75.6             19.0
# 44     Algeria  2003  Developing             71.7            146.0
# 45     Algeria  2002  Developing             71.6            145.0
# 46     Algeria  2001  Developing             71.4            145.0
# 47     Algeria  2000  Developing             71.3            145.0
# ...        ...   ...         ...              ...              ...
# 2918    Zambia  2003  Developing             46.4             64.0
# 2919    Zambia  2002  Developing             45.5             69.0
# 2920    Zambia  2001  Developing             44.6            611.0
# 2921    Zambia  2000  Developing             43.8            614.0
# 2922  Zimbabwe  2015  Developing             67.0            336.0
#
#       Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  \
# 32               21      NaN                0.000000         95.0       63
# ...

# %%
dataset.loc[null_indices].isna().sum(axis=1).mean()
# Out:
# 1.9883630721489527

# %%
import missingno as msno

# %%
msno.matrix(dataset)
# Out:
# <AxesSubplot:>

# %%
msno.bar(dataset)
# Out:
# <AxesSubplot:>

# %%
new_columns=dataset.columns[dataset.isnull().mean()<=0.15]

# %%
dataset2 = dataset[new_columns]

# %%
msno.matrix(dataset2)
# Out:
# <AxesSubplot:>
